# %% [markdown]
# 1)
# Let's define the random variable $M_i=1-e^{-1}$ if a point is below $f(x)$ and  $M_i=0$ if it's above $f(x)$
# - each point $i$ is sampled uniformly in the rectangle $(0,0),(1,1-e^{-1})$ so :
#    - Probabilty That a point $i$ is below $C_f$  is  $\frac { \int_0^1 f(x) dx  } {1-e^{-1}} $  ie : $\frac{area \ under \ C_f}{area \ of \ the \ rectangel} $
#    - Then : $E(M_i) = \int_0^1 f(x) dx$
# - Now we choose the unbiased estimator of $E(M_i)$ , $m= \frac{1}{N} \sum_i M_i$ and by estimating $m$ that's allows to estimate the integral

# %%
# coding: utf-8

# In[1]:


import math
import random                     
import matplotlib.pyplot as plt    

n_trials = 15500  #change n               
n_inside = 0
inside_x = []
inside_y = []
outside_x = []
outside_y = []
p_max = 1-math.exp(-1) 
for i in range(n_trials):
    x, y = random.uniform(0.0, 1.0), random.uniform(0.0, 1.0) *p_max
    p_x = 1-math.exp(-x)
    if  p_x > y: 
        n_inside += 1
        inside_x.append(x)
        inside_y.append(y) 
    else:
        outside_x.append(x) 
        outside_y.append(y) 


plt.plot(inside_x, inside_y, 'x' )
plt.plot (outside_x, outside_y, '.')
plt.show()
print ("Integral approx = ", p_max * n_inside / float(n_trials))
# Out:
# Integral approx =  0.37095281310352

# %% [markdown]
# # An estimate of the error :

# %%
# In[8]:


import random                     
import matplotlib.pyplot as plt    
import math              
n_estimat= 1000
integ=math.exp(-1)
s=0
n_trials=1000

for j in range (n_estimat):     
    n_inside = 0
    for i in range(n_trials):
        x, y = random.uniform(0.0, 1.0), random.uniform(0.0, 1.0) *p_max
        p_x = 1-math.exp(-x)
        if  p_x > y: 
            n_inside += 1
    m= p_max * n_inside / float(n_trials)
    #print (m)
    s+= (m - integ)*(m-integ) 
s/= n_estimat
error=math.sqrt(s)
print ('Error is ', s)
#plt.p
# Out:
# Error is  9.704930094701266e-05

# %% [markdown]
# 2)
#   - we have $p_X(x)=2x$ in $[0,1[$ so The cumulative function of X is $F(x)=\int_0^x p(u)du = x^2 $
#      - Let's define the random variable $Y=F_X(x)$ so $y=x^2$ and  $x$ in $[0,1]$ $ \Rightarrow x=\sqrt{y}$
#        Using the cumulative method : Sampling y uniformly in $[0,1]$  $\Leftrightarrow$ sampling $x$ from $p_X(x)=2x$ .
#   ----------------------------------------------------------------------------------------------------------------------
#   - Sampling $x$ from $p_X(x)$ and then $y$ uniformly between  $[0,c P_X(x)[$ (with $c=0.5$) gives :
#    - $P_{X,Y} = P_X(x) P_{Y|X}(y) =  \frac{P_X(x)}{cP_X(x)} = 2$
#      So we get a uniform distribution and the domain of definition is $[0,1[$ for $X$ and [0,x[ for $Y$  $\Leftrightarrow$ the     point $(x,y)$ is under $y=x$.
#   So we generate points with a uniform distribution under the line $x$

# %%
# 


import random 
import math 
import matplotlib.pyplot as plt 

x_dat=[]
y_dat=[]
N=2300
for i in range (N):
    z=random.uniform(0.0, 1.0) 
    x=math.sqrt(z) 
    x_dat.append(x)
    px=2*x
    y=random.uniform(0.0,0.5*px)
    y_dat.append(y)

a_dat=[]
b_dat=[]

# for i in range (N):
   # a=random.uniform(0.0, 1.0) 
    #b=random.uniform(0.0,a)
    #a_dat.append(a)
    #b_dat.append(b) 
#print (len(x_dat), len(y_dat))
plt.plot([0,1], [0,1])
plt.plot(x_dat,y_dat,'x')
plt.show()


#plt.plot([0,1], [0,1])
#plt.plot(a_dat,b_dat,'x')
#plt.show()

# %% [markdown]
# # Using the last method to compute the integral :

# %%
# In[4]:


import math
import random                     
import matplotlib.pyplot as plt    

n_trials = 15500  #change n               
n_inside = 0
inside_x = []
inside_y = []
outside_x = []
outside_y = []
p_max = 1-math.exp(-1) 

for i in range(n_trials):
    z=random.uniform(0.0, 1.0) 
    x=math.sqrt(z)
    px=2*x
    y=random.uniform(0.0,0.5*px)
    p_x = 1-math.exp(-x)
    if  p_x > y: 
        n_inside += 1
        inside_x.append(x)
        inside_y.append(y) 
    else:
        outside_x.append(x) 
        outside_y.append(y) 


plt.plot(inside_x, inside_y, 'x' )
plt.plot (outside_x, outside_y, '.')
plt.plot([0,1], [0,1])
plt.show()
print ("Integral approx = ", 0.5 * n_inside / float(n_trials))
# Out:
# Integral approx =  0.3726774193548387

# %% [markdown]
# # Comparing the two methods :

# %%
# In[12]:


import random                     
import matplotlib.pyplot as plt    
import math              
n_estimat= 100
integ=math.exp(-1)
s=0
error_2=[]
error_1=[]

for n_trials in range (800,850):
    s1=0
    s2=0
    for j in range (n_estimat):     
        n_inside1 = 0
        n_inside2=0
        for i in range(n_trials):
            #method 1 
            x, y = random.uniform(0.0, 1.0), random.uniform(0.0, 1.0) *p_max
            p_x = 1-math.exp(-x)
            if  p_x > y: 
                n_inside1 += 1
            #method 2
            z=random.uniform(0.0, 1.0) 
            x=math.sqrt(z)
            px=2*x
            y=random.uniform(0.0,0.5*px)
            p_x = 1-math.exp(-x)
            if  p_x > y: 
                n_inside2 += 1
        m1= p_max * n_inside1 / float(n_trials)
        s1+= (m1 - integ)*(m1-integ)
    
        m2= 0.5 * n_inside2 / float(n_trials)
        s2+= (m2 - integ)*(m2-integ)
    s1/= n_estimat
    er1=math.sqrt(s1)
    error_1.append(er1)                       
    s2/= n_estimat
    er2=math.sqrt(s2)
    error_2.append(er2)
    

plt.plot (range(50),error_1,label='Method 1')
plt.plot (range(50),error_2, label= 'Method 2')
plt.legend(loc='center right')
plt.xlabel('n')
plt.ylabel('Error')
plt.show()

# %% [markdown]
# We notice that the error of the second method is lower in average.
#
# if we compute the Variance of the random variable $M_i$ :
#
#   a) In the first case  we have : $M_i=\{1-e^{-1},0\}$
#                  $$ \Rightarrow  Var_1(M_i)=E(M_i^2)-E(M_i)^2 = (1-e^{-1})\int_0^1 f(x) dx- (\int_0^1 f(x) dx)^{2}$$
#
#    b) in the second case :
#                $$\Rightarrow  Var_1(M_i)=E(M_i^2)-E(M_i)^2 = \frac{1}{2} \int_0^1 f(x) dx- (\int_0^1 f(x) dx)^{2}$$
#           bacause  $ (1-e^{-1})> \frac{1}{2}  \Rightarrow  Var_1(M_i)>Var_2(M_i) $
#           That's why the error of the second method is lower in average.

# %% [markdown]
# 3)
# We have $g(x) = (1-e^{-1})x^{\frac{1}{2}}$ and $f(x)= 1-e^{-x}$
# One can write : $$f(x)= \sum_n (-1)^n \frac{x^{n+1}}{n+1!}$$
# $$ \Rightarrow \frac{1-e^{-x}}{x^{\frac{1}{2}}}= \sum_n (-1)^n\frac{x^{n+\frac{1}{2}}}{n+1!}$$
# and because $x$ is in $[0,1[$
#   $$ \sum_n (-1)^n\frac{x^{n+\frac{1}{2}}}{n+1!}< \sum_n (-1)^n\frac{1}{n+1!} = 1-e^{-1} $$
#    $$ \Rightarrow \frac{1-e^{-x}}{x^{\frac{1}{2}}} < 1-e^{-1} \Rightarrow f(x) < g(x)= x^{\frac{1}{2}}(1-e^{-1}) $$

# %% [markdown]
# and compute $c$ such that $g(x)=c*p_x(x)$.
# - Using the method of cumulative function we can  generate random numbers $x$ from $p_x(x)=\frac 32 \sqrt x$ :
#      $$ F_X(x)= x^\frac 32 $$
#      if we consider $z = F_X(x)$ then $x=y^{\frac 23} $  by sampling $z$ uniformly in [0,1] we get random numbers $x$ from $p_x(x)=\frac 32 \sqrt x$
#
# - we have $g(x) = (1-e^{-1}) x^\frac 12 = c \frac 32 \sqrt x \Rightarrow  c= (1-e^{-1}) \frac 23 $
#
# Simlarly to question 2 :
# By sampling  $x$ from $p_x(x)=\frac 32 \sqrt x$ and $y$ uniformly in $[0,cP_X(x)[ $ we generate uniformly random points below $g(x)$
#
#
# ## Using this method we reduce the probability of rejection and then we get more precise results

# %%
# In[11]:


import math
import random                     
import matplotlib.pyplot as plt    

n_trials = 15500  #change n               
n_inside = 0
inside_x = []
inside_y = []
outside_x = []
outside_y = []
p_max = 1-math.exp(-1) 
c=(2/3)*p_max
a_tot= p_max * (2/3)
for i in range(n_trials):
    z=random.uniform(0.0, 1.0) 
    x=z**(2/3)
    px=(3/2)*x**(1/2)
    y=random.uniform(0.0,c*px)
    p_x = 1-math.exp(-x)
    if  p_x > y: 
        n_inside += 1
        inside_x.append(x)
        inside_y.append(y) 
    else:
        outside_x.append(x) 
        outside_y.append(y) 


plt.plot(inside_x, inside_y, 'x' )
plt.plot (outside_x, outside_y, '.')
plt.plot([0,1], [0,1])
plt.show()
print ("Integral approx = ", a_tot * n_inside / float(n_trials))
# Out:
# Integral approx =  0.3699468578055993

# %%
# In[15]:


import random                     
import matplotlib.pyplot as plt    
import math              
n_estimat= 100
integ=math.exp(-1)
s=0
error_2=[]
error_1=[]
error_3=[]
p_max = 1-math.exp(-1) 
c=(2/3)*p_max
a_tot= p_max * (2/3)
for n_trials in range (800,850):
    s1=0
    s2=0
    s3=0
    for j in range (n_estimat):     
        n_inside1 = 0
        n_inside2=0
        n_inside3=0
        for i in range(n_trials):
            #method 1 
            x, y = random.uniform(0.0, 1.0), random.uniform(0.0, 1.0) *p_max
            p_x = 1-math.exp(-x)
            if  p_x > y: 
                n_inside1 += 1
            #method 2
            z=random.uniform(0.0, 1.0) 
            x=math.sqrt(z)
            px=2*x
            y=random.uniform(0.0,0.5*px)
            p_x = 1-math.exp(-x)
            if  p_x > y: 
                n_inside2 += 1
            #method 3 
            z=random.uniform(0.0, 1.0) 
            x=z**(2/3)
            px=(3/2)*x**(1/2)
            y=random.uniform(0.0,c*px)
            p_x = 1-math.exp(-x)
            if  p_x > y: 
                n_inside3 += 1
                
        m1= p_max * n_inside1 / float(n_trials)
        s1+= (m1 - integ)*(m1-integ)
    
        m2= 0.5 * n_inside2 / float(n_trials)
        s2+= (m2 - integ)*(m2-integ)
        
        m3= a_tot * n_inside3 / float(n_trials)
        s3+= (m3 - integ)*(m3-integ)
        
    s1/= n_estimat
    er1=math.sqrt(s1)
    error_1.append(er1)                       
    s2/= n_estimat
    er2=math.sqrt(s2)
    error_2.append(er2)
    s3/= n_estimat
    er3=math.sqrt(s3)
    error_3.append(er3)
    

plt.plot (range(50),error_1,label='Method 1')
plt.plot (range(50),error_2, label= 'Method 2')
plt.plot (range(50),error_3, label= 'Method 3')
plt.legend(loc='center right')
plt.xlabel('n')
plt.ylabel('Error')
plt.show()
